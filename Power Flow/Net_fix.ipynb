# %% [markdown]
# # **Power Flow / Flujo de Potencia**
# Este código en Python utiliza la biblioteca Pandapower para modelar y simular una red eléctrica monofásica. Primero, carga datos de entrada de diferentes componentes de la red, como buses, líneas, transformadores y cargas, desde hojas de cálculo de Excel. Luego, crea un modelo de red vacío y lo rellena con estos componentes. Adicionalmente, utiliza un perfil de demanda para ajustar dinámicamente las cargas en la red a lo largo del tiempo. Finalmente, ejecuta un flujo de potencia para cada instante temporal del perfil de demanda y almacena los resultados en hojas de cálculo para su posterior análisis.

# %%
#------------------------------------------------------------------------  librerias  -----------------------------------------------------------------------------------#

import numpy as np
import pandas as pd
import pandapower as pp
from pandapower.pf.runpp_3ph import runpp_3ph
from pandapower.plotting.plotly import simple_plotly
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from pandapower.plotting.plotly import pf_res_plotly
import networkx as nx
from rtree import index

# %%
def get_main_grid_buses(G, start_bus):
    # Inicializar una cola para el algoritmo BFS
    queue = [start_bus]
    # Inicializar un conjunto para almacenar los buses visitados
    visited = set()
    
    while queue:
        # Sacar el primer bus de la cola
        current_bus = queue.pop(0)
        # Marcar el bus actual como visitado
        visited.add(current_bus)
        # Obtener todos los vecinos del bus actual
        neighbors = list(G.neighbors(current_bus))
        # Agregar los vecinos no visitados a la cola
        for neighbor in neighbors:
            if neighbor not in visited and neighbor not in queue:
                queue.append(neighbor)
    return visited

def create_rtree(buses, net):
    rtree = index.Index()
    for bus in buses:
        if bus in net.bus_geodata.index:  # Solo considera buses con geodata
            x, y = net.bus_geodata.loc[bus, ['x', 'y']]
            rtree.insert(bus, (x, y, x, y))
    return rtree

def find_closest_section_and_bus(disconnected_sections, main_grid_buses, net):
    closest_section = None
    closest_bus = None
    closest_main_bus = None
    min_distance = float('inf')
    
    main_grid_rtree = create_rtree(main_grid_buses, net)
    
    for section in disconnected_sections:
        for disconnected_bus in section:
            if disconnected_bus not in net.bus_geodata.index:
                continue  
            
            x1, y1 = net.bus_geodata.loc[disconnected_bus, ['x', 'y']]
            epsilon = 1e-6
            nearest = list(main_grid_rtree.nearest((x1 - epsilon, y1 - epsilon, x1 + epsilon, y1 + epsilon), 1))
            if nearest:
                main_grid_bus = nearest[0]
                x2, y2 = net.bus_geodata.loc[main_grid_bus, ['x', 'y']]
                distance = np.sqrt((x2 - x1)**2 + (y2 - y1)**2)
                if distance > 0 and distance < min_distance:
                    min_distance = distance
                    closest_section = section
                    closest_bus = disconnected_bus
                    closest_main_bus = main_grid_bus
    
    print(f'Closest section: {closest_section}, closest bus: {closest_bus}, closest main_bus: {closest_main_bus}, min_distance: {min_distance}')
    return closest_section, closest_bus, closest_main_bus, min_distance

def connect_disconnected_sections(net, G):
    disconnected_sections = list(pp.topology.connected_components(G))
    main_grid_buses = get_main_grid_buses(G, 0)  # Función ya definida para encontrar la red principal
    new_connections = []
    line_counter = 1  # Inicializar un contador para los nombres de las nuevas líneas

    while disconnected_sections:
        print(f'Number of disconnected sections: {len(disconnected_sections)}')
        closest_section, closest_bus, closest_main_bus, min_distance = find_closest_section_and_bus(disconnected_sections, main_grid_buses, net)
        if closest_bus is not None and closest_main_bus is not None:
            existing_lines = net.line[(net.line.from_bus == closest_bus) & (net.line.to_bus == closest_main_bus)]
            if existing_lines.empty:
                # Asignar un nombre único a la línea, por ejemplo: 'New Line 1', 'New Line 2', etc.
                line_name = f'New Line {line_counter} Alimentador {Alimentador}'
                new_connections.append((closest_bus, closest_main_bus, line_name))
                min_distance_km = min_distance*1000
                pp.create_line(net, from_bus=closest_bus, to_bus=closest_main_bus, length_km= 0.5, std_type="NAYY 4x50 SE", name=line_name)
                print(f'Connected bus {closest_bus} to {closest_main_bus} with {line_name}')
                line_counter += 1  # Incrementar el contador para el siguiente nombre único
            else:
                print(f'Connection already exists between bus {closest_bus} and {closest_main_bus}')

            G = pp.topology.create_nxgraph(net, multi=False)
            main_grid_buses = get_main_grid_buses(G, 0)
            disconnected_sections = list(pp.topology.connected_components(G))
            disconnected_sections = [s for s in disconnected_sections if s != closest_section]
        else:
            print('No closest bus or main bus found, exiting loop')
            break

    return net, new_connections

# %%
# Función para crear la red eléctrica
def crear_red_electrica(Filename,Alimentador):
    # Definición de DataFrames para diferentes componentes de la red
    hv_bus = pd.read_excel(Filename, sheet_name="buses", index_col=[0])  # Buses

    hv_lines = pd.read_excel(Filename, sheet_name="lineas")  # Líneas

    hv_trafo = pd.read_excel(Filename, sheet_name="transformadores")  # Transformadores

    hv_grid = pd.read_excel(Filename, sheet_name="grid")  # Red externa

    Catalogo_conductor = pd.read_excel(Filename, sheet_name="catalogo_conductor")  # Catálogo de conductores

    Banco_cond = pd.read_excel(Filename, sheet_name="Banco_cond")  # Bancos de condensadores

    bus_indices_to_drop = hv_bus[hv_bus['vn_kv'].isin([0.22, 0.38]) | hv_bus['vn_kv'].isna()].index

    # Eliminar buses de baja tensión :
    hv_bus = hv_bus.drop(bus_indices_to_drop)

    # Identificar los bus_id que están presentes en la columna bus_hv de hv_trafo y también en hv_bus
    valid_bus_ids_hv_trafo = set(hv_trafo['bus_hv'].unique()) & set(hv_bus.index)

    # Obtener los índices de los buses válidos desde el DataFrame de buses
    valid_bus_indices = set(hv_bus.index)

    # Identificar las líneas que tienen buses de conexión no válidos
    # Comprobamos tanto el bus de origen ('from_bus') como el bus de destino ('to_bus')
    invalid_lines = hv_lines[~(hv_lines['from_bus'].isin(valid_bus_indices) & hv_lines['to_bus'].isin(valid_bus_indices))]

    # Eliminar las líneas no válidas del DataFrame hv_lines
    hv_lines = hv_lines.drop(invalid_lines.index)

    # Crear una red vacía
    net = pp.create_empty_network()

    # Definir buses
    for _, bus_df in hv_bus.iterrows():
        pp.create_bus(net, name=bus_df.name, vn_kv=bus_df.vn_kv, type="n", 
                      in_service=True, geodata=(bus_df.lat, bus_df.long))

    # Definir catálogo de conductores
    for _, conductor_df in Catalogo_conductor.iterrows():
        std_type = {
            "max_i_ka": conductor_df.max_i_ka,
            "r_ohm_per_km": conductor_df.r_ohm_per_km,
            "x_ohm_per_km": conductor_df.x_ohm_per_km,
            "c_nf_per_km": conductor_df.c_nf_per_km,
            "g_us_per_km": conductor_df.g_us_per_km
        }
        pp.create_std_type(net, std_type, name=conductor_df.Conductor_id, element="line")

    # Definir líneas
    for _, line_df in hv_lines.iterrows():
        from_bus = pp.get_element_index(net, "bus", line_df.from_bus)
        to_bus = pp.get_element_index(net, "bus", line_df.to_bus)
        pp.create_line(net, from_bus, to_bus, length_km=line_df.length_km,
                       std_type=line_df.std_type, name=line_df.line_name, 
                       in_service=True, df=1.0, parallel=1)

    # Definir red externa
    for _, grid_df in hv_grid.iterrows():
        bus_idx = pp.get_element_index(net, "bus", grid_df.bus)
        pp.create_ext_grid(net, bus_idx, vm_pu=grid_df.vm_pu,
                           va_degree=grid_df.va_degree, name=grid_df.grid_name, in_service=True)

    # Definir banco de condensadores
    for _, bank_df in Banco_cond.iterrows():
        bus_idx = pp.get_element_index(net, "bus", bank_df.bus)
        pp.create_shunt_as_capacitor(
            net, bus_idx, name=bank_df.bank_name, q_mvar=bank_df.q_mvar,
            loss_factor=bank_df.loss_factor, vn_kv=bank_df.vn_kv, in_service=True)
    
    pp.diagnostic(net, report_style='detailed', warnings_only=True, return_result_dict=True, overload_scaling_factor=0.001, min_r_ohm=0.001,
                           min_x_ohm=0.001, min_r_pu=1e-05, min_x_pu=1e-05, nom_voltage_tolerance=0.3, numba_tolerance=1e-05)
    
    G = pp.topology.create_nxgraph(net, multi=False)

    # Obtener el conjunto de buses en la red principal
    main_grid_buses = get_main_grid_buses(G, 0)
    
    net.bus_geodata = net.bus_geodata.dropna(subset=['x', 'y'])

    # Llamar a la función para conectar las secciones desconectadas
    net, new_connections = connect_disconnected_sections(net, G)

     # Ejecutar diagnóstico
    result_dict = pp.diagnostic(net, report_style='detailed', warnings_only=False, return_result_dict=True, overload_scaling_factor=0.001, min_r_ohm=0.001,
                           min_x_ohm=0.001, min_r_pu=1e-05, min_x_pu=1e-05, nom_voltage_tolerance=0.3, numba_tolerance=1e-05)
    # Inicializar listas para almacenar elementos desconectados
    disconnected_buses = []
    disconnected_lines = []
    disconnected_transformers = []
    disconnected_loads = []
    # Extraer y almacenar elementos desconectados
    for section in result_dict.get('disconnected_elements', []):
        disconnected_buses.extend(section.get('buses', []))
        disconnected_lines.extend(section.get('lines', []))
        disconnected_transformers.extend(section.get('trafos', []))
        disconnected_loads.extend(section.get('loads', []))

    # Eliminar duplicados (si los hay)
    disconnected_buses = list(set(disconnected_buses))
    disconnected_lines = list(set(disconnected_lines))
    disconnected_transformers = list(set(disconnected_transformers))
    disconnected_loads = list(set(disconnected_loads))
        # Eliminación de elementos desconectados
    for bus in disconnected_buses:
        net.bus.drop(bus, inplace=True)

    for line in disconnected_lines:
        net.line.drop(line, inplace=True)

    for trafo in disconnected_transformers:
        net.trafo.drop(trafo, inplace=True)

    for load in disconnected_loads:
        net.load.drop(load, inplace=True)

    bus_index_to_name = net.bus['name'].to_dict()
    
    # Agrega nuevas columnas 'from_bus_name' y 'to_bus_name' al DataFrame net.line
    net.line['from_bus_name'] = net.line['from_bus'].map(bus_index_to_name)
    net.line['to_bus_name'] = net.line['to_bus'].map(bus_index_to_name)
    
    net.trafo['hv_bus_name'] = net.trafo.hv_bus.map(bus_index_to_name)
    net.trafo['lv_bus_name'] = net.trafo.lv_bus.map(bus_index_to_name)
    net.ext_grid['bus_name'] = net.ext_grid.bus.map(bus_index_to_name)
    net.shunt['bus_name'] = net.shunt.bus.map(bus_index_to_name)
    bus_data = pd.merge(net.bus, net.bus_geodata, how='left', left_index=True, right_index=True)
    bus_data['alimentador'] = Alimentador
    net.bus_geodata['Alimentador'] = Alimentador
    net.line['alimentador'] = Alimentador
    net.trafo['alimentador'] = Alimentador
    net.ext_grid['alimentador'] = Alimentador
    net.load['alimentador'] = Alimentador
    net.shunt['alimentador'] = Alimentador
    Catalogo_conductor['alimentador'] = Alimentador
    with pd.ExcelWriter(f'Output\Alimentador{Alimentador}_corregido.xlsx') as writer:
        bus_data.to_excel(writer, sheet_name='Bus Data', index =False)
        net.line.to_excel(writer, sheet_name='Line Data')
        net.trafo.to_excel(writer, sheet_name='Transformer Data')
        net.ext_grid.to_excel(writer, sheet_name='External Grid Data')
        net.load.to_excel(writer, sheet_name='Load Data')
        net.shunt.to_excel(writer, sheet_name='Shunt Data')
        Catalogo_conductor.to_excel(writer, sheet_name='std_type Data')

    return net

# %%
Filename = "Input\Alimentadores\Alimentador677.xlsx"  # Datos de la red
Alimentador = 677
crear_red_electrica(Filename,Alimentador)

Filename = "Input\Alimentadores\Alimentador675.xlsx"  # Datos de la red
Alimentador = 675
crear_red_electrica(Filename,Alimentador)

Filename = "Input\Alimentadores\Alimentador665.xlsx"  # Datos de la red
Alimentador = 665
crear_red_electrica(Filename,Alimentador)

Filename = "Input\Alimentadores\Alimentador678.xlsx"  # Datos de la red
Alimentador = 678
crear_red_electrica(Filename,Alimentador)
# Out:
# _____________ PANDAPOWER DIAGNOSTIC TOOL _____________
#
# Checking for elements without a connection to an external grid...
#
# Disconnected section found, consisting of the following elements:
# buses: [0, 171, 478, 479, 644, 658, 664, 1382, 1383, 1604, 1718, 1928, 1932, 1934, 1961, 2164, 2171, 2368]
# lines: [1090, 1094, 1097, 1129, 2058, 1069, 1678, 2061, 1105, 1106, 1107, 2065, 1077, 2067, 2070, 2073, 1087]
# Disconnected section found, consisting of the following elements:
# buses: [1, 15, 205, 265, 370, 386, 1095, 1265, 1302, 1308, 1310, 1311, 1318, 1321, 1325, 1350, 1351, 1473, 1495, 1503, 1520, 1521, 1530, 1531, 1534, 1682, 1692, 1782, 1938, 2008, 2022, 2024, 2178, 2385]
# lines: [777, 526, 783, 914, 787, 916, 792, 538, 926, 799, 543, 548, 804, 945, 562, 820, 693, 948, 830, 834, 585, 588, 977, 599, 986, 732, 989, 991, 624, 752, 882, 758, 766]
# Disconnected section found, consisting of the following elements:
# buses: [2, 99, 1846, 2101]
# lines: [2005, 1658, 1989]
# Disconnected section found, consisting of the following elements:
# buses: [3, 154, 158, 166, 168, 176, 187, 226, 268, 276, 327, 331, 342, 357, 528, 602, 684, 692, 724, 730, 837, 840, 848, 859, 909, 917, 949, 960, 976, 1041, 1061, 1079, 1115, 1722, 1785, 1821, 1825, 1826, 1834, 1844, 1967, 2176, 2192, 2218, 2247, 2257, 2261, 2271, 2276, 2278, 2280, 2283, 2302, 2304, 2313, 2320, 2359]
# lines: [1802, 786, 1814, 535, 1687, 1786, 1691, 801, 802, 934, 937, 810, 171, 555, 683, 558, 685, 1714, 564, 694, 951, 953, 827, 957, 1732, 583, 711, 840, 968, 715, 1736, 589, 846, 975, 720, 81, 850, 976, 1742, 726, 984, 1754, 731, 1501, 994, 739, 867, 1509, 870, 1762, 620, 1517, 1524, 1526, 888, 762]
# Disconnected section found, consisting of the following elements:
# buses: [4, 1002, 1063, 2379]
# lines: [1924, 956, 692]
# Disconnected section found, consisting of the following elements:
# buses: [5, 88, 92, 93, 94, 95, 96, 97, 98, 100, 101, 102, 103, 104, 105, 108, 122, 201, 216, 256, 270, 284, 476, 687, 696, 708, 710, 722, 749, 786, 793, 805, 812, 813, 984, 1215, 1364, 1398, 1402, 1417, 1454, 1469, 1504, 1506, 1511, 1572, 1623, 1626, 1627, 1629, 1633, 1638, 1657, 1658, 1668, 1679, 1694, 1720, 1724, 1731, 1736, 1740, 1749, 1781, 1783, 1791, 1795, 1804, 1840, 1853, 1885, 1895, 2058, 2081, 2089, 2153, 2167, 2172, 2216, 2217, 2226, 2235, 2251, 2254, 2263, 2273, 2312, 2324, 2429]
# lines: [2059, 2064, 2072, 1584, 1590, 1597, 1600, 1645, 1648, 1655, 1143, 2168, 2170, 2171, 1148, 2175, 2176, 1153, 1665, 1155, 1156, 1669, 1158, 2177, 2179, 2181, 1162, 2187, 1164, 1165, 1677, 1167, 1679, 2188, 2189, 2190, 2194, 2195, 1174, 1175, 2196, 2198, 2201, 2202, 2205, 2206, 1187, 1190, 1194, 1195, 1196, 1708, 1709, 1199, 1210, 1212, 1726, 1217, 1218, 1219, 1220, 1731, 1735, 1738, 1227, 1746, 1236, 1240, 1752, 1243, 1244, 1763, 2182, 2183, 1788, 1797, 1804, 1813, 333, 1972, 1973, 1976, 1981, 1985, 1986, 1987, 2010, 491]
# Disconnected section found, consisting of the following elements:
# buses: [6, 64, 139, 146, 248, 254, 262, 568, 613, 621, 732, 1253]
# lines: [806, 775, 1769, 1790, 753, 531, 982, 760, 761, 1725, 606]
# Disconnected section found, consisting of the following elements:
# buses: [7, 1241]
# lines: [811]
# Disconnected section found, consisting of the following elements:
# buses: [8, 421, 852, 1160, 1667, 1790, 2076, 2092]
# lines: [421, 422, 332, 335, 465, 379, 318]
# Disconnected section found, consisting of the following elements:
# buses: [9, 469, 554, 818, 1354, 1386, 1862]
# lines: [258, 325, 459, 371, 339, 470]
# Disconnected section found, consisting of the following elements:
# buses: [10, 220, 341, 401, 648, 700, 1598, 1788, 2043]
# lines: [257, 290, 484, 428, 500, 376, 410, 251]
# Disconnected section found, consisting of the following elements:
# buses: [11, 1362]
# lines: [680]
# Disconnected section found, consisting of the following elements:
# buses: [12, 706]
# lines: [632]
# Disconnected section found, consisting of the following elements:
# buses: [13, 68]
# lines: [2218]
# Disconnected section found, consisting of the following elements:
# buses: [14, 117]
# lines: [655]
# Disconnected section found, consisting of the following elements:
# buses: [16, 2219]
# lines: [627]
# Disconnected section found, consisting of the following elements:
# buses: [17, 2249]
# lines: [651]
# Disconnected section found, consisting of the following elements:
# buses: [18, 52, 236, 359, 378, 380, 385, 393, 404, 564, 839]
# lines: [1696, 2112, 2145, 2147, 2122, 2124, 563, 2132, 2102, 2105]
# Disconnected section found, consisting of the following elements:
# buses: [19, 2224]
# lines: [670]
# Disconnected section found, consisting of the following elements:
# buses: [20, 125, 438, 792, 814, 1688, 1691]
# lines: [1188, 1226, 1228, 1237, 1146, 1150]
# Disconnected section found, consisting of the following elements:
# buses: [21, 22, 178, 311, 344, 505, 559, 580, 626, 744, 745, 780, 788, 827, 842, 1114, 1137, 1210, 1213, 1221, 1240, 1246, 1281, 1537, 1546, 1605, 1615, 1945, 1964, 1971, 2182, 2259]
# lines: [770, 1171, 1173, 1176, 928, 1184, 1062, 1191, 1064, 1070, 1073, 1074, 1075, 1206, 1080, 710, 1095, 1098, 1238, 1111, 1116, 1245, 1120, 995, 996, 613, 1123, 1134, 1137, 755, 1142]
# Disconnected section found, consisting of the following elements:
# buses: [23, 37]
# lines: [2212]
# Disconnected section found, consisting of the following elements:
# buses: [24, 1888]
# lines: [717]
# Disconnected section found, consisting of the following elements:
# buses: [25, 364, 407, 411, 425, 614, 1303, 1342, 1377, 1393, 1441]
# lines: [1222, 1231, 1136, 1201, 1233, 1204, 1207, 1145, 1179, 1213]
# Disconnected section found, consisting of the following elements:
# buses: [26, 467, 1486, 1525]
# lines: [472, 433, 243]
# Disconnected section found, consisting of the following elements:
# buses: [27, 28, 246, 260, 261, 291, 368, 389, 398, 426, 435, 494, 716, 881, 914, 950, 958, 968, 987, 1108, 1112, 1151, 1169, 1170, 1177, 1184, 1239, 1247, 1408, 1429, 1435, 1447, 1448, 1483, 1519, 1648, 1683, 1845, 2039, 2050, 2073, 2111, 2120, 2175, 2190, 2191, 2201, 2203]
# lines: [768, 903, 912, 913, 917, 794, 795, 796, 923, 932, 551, 552, 939, 812, 557, 174, 813, 688, 177, 690, 179, 814, 821, 941, 697, 570, 958, 578, 836, 712, 716, 847, 981, 854, 727, 855, 985, 858, 603, 862, 607, 735, 103, 105, 746, 622, 887]
# Disconnected section found, consisting of the following elements:
# buses: [29, 30, 54, 120, 346, 562, 736, 906, 1020, 1049, 1089, 1091, 1096, 1099, 1122, 1131, 1142, 1155, 1236, 1258, 1373, 1538, 1568, 1697, 1699, 1725, 1761, 1799, 1800, 1801, 1914, 2005, 2075, 2077, 2186, 2227, 2240]
# lines: [1793, 774, 1799, 536, 537, 931, 1701, 565, 822, 1718, 955, 1723, 829, 574, 575, 709, 969, 714, 971, 974, 1743, 852, 597, 853, 1748, 602, 988, 736, 609, 997, 1766, 616, 617, 873, 750, 756]
# Disconnected section found, consisting of the following elements:
# buses: [31, 32]
# lines: [1721]
# Disconnected section found, consisting of the following elements:
# buses: [33]
# Disconnected section found, consisting of the following elements:
# buses: [34, 704]
# lines: [636]
# Disconnected section found, consisting of the following elements:
# buses: [35, 298, 300, 367]
# lines: [640, 649, 630]
# Disconnected section found, consisting of the following elements:
# buses: [36, 318, 1591, 1798, 1815, 2287]
# lines: [1058, 1110, 1083, 1084, 1085]
# Disconnected section found, consisting of the following elements:
# buses: [38, 87]
# lines: [1761]
# Disconnected section found, consisting of the following elements:
# buses: [39, 41, 46]
# lines: [2216, 2219]
# Disconnected section found, consisting of the following elements:
# buses: [40, 183, 396, 753, 892, 1073, 1291, 1301, 2036]
# lines: [320, 353, 387, 483, 362, 397, 439, 446]
# Disconnected section found, consisting of the following elements:
# buses: [42, 45, 118, 124, 287, 448, 452, 924]
# lines: [897, 679, 653, 660, 629, 667, 671]
# Disconnected section found, consisting of the following elements:
# buses: [43, 44, 1406, 1836]
# lines: [2217, 2221, 2223]
# Disconnected section found, consisting of the following elements:
# buses: [47, 111, 112, 113, 620, 633, 637, 642, 652, 660, 673, 676]
# lines: [1794, 745, 1719, 1737, 878, 1720, 1777, 1683, 884, 567, 728]
# Disconnected section found, consisting of the following elements:
# buses: [48, 541, 575, 586, 589, 604, 605, 1206]
# lines: [482, 388, 454, 424, 336, 369, 440]
# Disconnected section found, consisting of the following elements:
# buses: [49, 106, 109, 293, 445, 532, 647, 661, 683, 691, 729, 760, 766, 824, 905, 908, 1075, 1097, 1109, 1123, 1214, 1426, 1729, 1765, 1869, 2142, 2174]
# lines: [1157, 1159, 1168, 1041, 1043, 1044, 789, 1046, 1182, 1185, 556, 1202, 1205, 952, 1211, 704, 1224, 1230, 1235, 1771, 1135, 1011, 1012, 1139, 1140, 1149]
# Disconnected section found, consisting of the following elements:
# buses: [50, 159, 271, 356, 375, 414, 437, 446, 462, 477, 486, 499, 501, 515, 539, 553, 572, 582, 595, 608, 624, 650, 682, 709, 714, 855, 925, 940, 997, 1116, 1165, 1175, 1208, 1334, 1370, 1372, 1403, 1463, 1471, 1499, 1518, 1552, 1607, 1728, 1737, 1758, 1763, 1936, 1939, 1989, 2021, 2103, 2160, 2162, 2165, 2194]
# lines: [1281, 1282, 1283, 1667, 1285, 1670, 1287, 2050, 1673, 2051, 2055, 142, 790, 918, 1816, 797, 30, 161, 162, 930, 36, 1571, 1577, 1324, 1663, 1588, 1592, 1593, 1594, 189, 1599, 1346, 1603, 68, 1608, 587, 844, 1615, 1617, 1620, 1621, 474, 1632, 354, 1635, 111, 1653, 1654, 254, 2038, 2041, 1660, 1277, 1278, 1279]
# Disconnected section found, consisting of the following elements:
# buses: [51, 816, 1413, 1445, 1450, 1490]
# lines: [224, 2, 119, 89, 124]
# Disconnected section found, consisting of the following elements:
# buses: [53, 1190]
# lines: [2224]
# Disconnected section found, consisting of the following elements:
# buses: [55, 279, 878, 879, 1275, 1569, 1571, 1579, 1583, 1593, 1597, 1620, 1621, 1622, 1624, 1628, 1647, 2328, 2332, 2352, 2361, 2364]
# lines: [147, 21, 155, 160, 164, 181, 203, 82, 213, 1247, 1248, 1249, 1258, 1259, 1260, 1261, 1266, 1267, 1271, 1272, 1274]
# Disconnected section found, consisting of the following elements:
# buses: [56, 155, 161, 169, 173, 181, 196, 206, 269, 281, 825, 843, 1464, 1465, 1881, 1892, 1894, 1908, 1912, 2346, 2363]
# lines: [1805, 1681, 1809, 1810, 1689, 1690, 1818, 1692, 1693, 1694, 52, 183, 1722, 1727, 1728, 1747, 1751, 221, 1759, 1778]
# Disconnected section found, consisting of the following elements:
# buses: [57, 701, 967, 1238, 1416, 1420, 1424, 1433, 1446]
# lines: [1121, 1128, 1066, 1067, 1103, 1104, 1112, 1114]
# Disconnected section found, consisting of the following elements:
# buses: [58, 912, 969, 988, 1081, 1200]
# lines: [1254, 1255, 1264, 1269, 1273]
# Disconnected section found, consisting of the following elements:
# buses: [59, 60, 1400]
# lines: [1252, 1253]
# Disconnected section found, consisting of the following elements:
# buses: [61, 1012, 1127, 1205, 1267, 1333]
# lines: [1250, 1256, 1268, 1275, 1276]
# Disconnected section found, consisting of the following elements:
# buses: [62, 66, 1268]
# lines: [1265, 1262]
# Disconnected section found, consisting of the following elements:
# buses: [63, 199, 308, 312, 333, 335, 338, 345, 362, 1545, 1595, 1651, 1652]
# lines: [896, 673, 646, 669, 678, 893, 662, 663, 633, 635, 637, 639]
# Disconnected section found, consisting of the following elements:
# buses: [65, 69, 70, 72, 76, 79, 91, 110, 128, 321, 680, 705, 815, 1015, 1078, 1237, 1243, 1244, 1248, 1276, 1282, 1287, 1292, 1407, 1458, 1916, 1948, 1950, 2185, 2372]
# lines: [904, 908, 2207, 2210, 2211, 2213, 2215, 1968, 2225, 2227, 2228, 1974, 1975, 1977, 1984, 705, 1990, 1991, 978, 2002, 2003, 2004, 2006, 2007, 600, 2008, 2011, 2012, 2017]
# Disconnected section found, consisting of the following elements:
# buses: [67, 1876, 2382]
# lines: [859, 805]
# Disconnected section found, consisting of the following elements:
# buses: [71, 107, 214, 232, 240, 538, 540, 542, 557, 617, 774, 1134, 1211, 1340, 1779, 1818, 1837, 1870, 1872, 1879, 1903, 1915, 2244, 2290, 2357, 2386, 2387]
# lines: [513, 518, 519, 520, 522, 523, 272, 684, 1966, 2226, 2229, 1978, 1979, 1988, 1992, 1996, 1999, 2000, 2001, 2013, 738, 2018, 240, 507, 508, 511]
# Disconnected section found, consisting of the following elements:
# buses: [73, 89, 129, 130, 131, 138, 200, 221, 239, 243, 245, 1130, 1144, 1523]
# lines: [1765, 2150, 2151, 1706, 2090, 2091, 2154, 2222, 1713, 2098, 1781, 2103, 1753]
# Disconnected section found, consisting of the following elements:
# buses: [74]
# Disconnected section found, consisting of the following elements:
# buses: [75, 2388]
# lines: [2220]
# Disconnected section found, consisting of the following elements:
# buses: [77, 297, 1412, 1453, 1920, 2225]
# lines: [615, 584, 1014, 1016, 1819]
# Disconnected section found, consisting of the following elements:
# buses: [78, 82, 225, 244, 251, 252, 255, 306, 324]
# lines: [2208, 2209, 2082, 2084, 2087, 1767, 2088, 2077]
# Disconnected section found, consisting of the following elements:
# buses: [80, 741, 2180]
# lines: [309, 375]
# Disconnected section found, consisting of the following elements:
# buses: [81, 1565, 2214]
# lines: [1699, 1756]
# Disconnected section found, consisting of the following elements:
# buses: [83, 674]
# lines: [835]
# Disconnected section found, consisting of the following elements:
# buses: [84, 1678, 2260]
# lines: [730, 966]
# Disconnected section found, consisting of the following elements:
# buses: [85, 116]
# lines: [894]
# Disconnected section found, consisting of the following elements:
# buses: [86, 316, 339, 340, 347, 349, 371, 640]
# lines: [2214, 2136, 2137, 2138, 2139, 2140, 2141]
# Disconnected section found, consisting of the following elements:
# buses: [90, 119, 148, 149, 247, 258, 263, 919, 1391, 1395, 1438, 1557, 1560, 1564, 1585, 1613, 1733, 1735, 1755, 1769, 1796, 1810, 1817, 1819, 1865, 1866, 1867, 1874, 1877, 1882, 1884, 1926, 1972, 2004, 2037, 2044, 2181, 2335, 2347, 2365, 2366, 2383]
# lines: [2048, 2049, 2052, 2053, 2054, 2056, 1060, 1578, 1970, 1971, 1982, 1983, 1092, 1993, 1994, 1101, 1997, 1998, 1618, 2009, 1629, 2014, 1631, 2015, 2016, 1122, 2019, 1636, 2020, 1638, 1127, 2036, 2037, 2039, 2040, 2042, 2043, 2044, 2045, 2046, 2047]
# Disconnected section found, consisting of the following elements:
# buses: [114, 115]
# lines: [1772]
# Disconnected section found, consisting of the following elements:
# buses: [121, 132, 134, 137, 215, 1017, 1556, 1582, 1608, 2341]
# lines: [899, 1764, 1733, 713, 1803, 973, 1711, 819, 793]
# Disconnected section found, consisting of the following elements:
# buses: [123, 208, 288, 490, 502, 516, 524, 930, 1544, 1549, 1554, 1573, 1617, 1851, 2155]
# lines: [1026, 964, 708, 1029, 1030, 1031, 1033, 1035, 1774, 1013, 1015, 1018, 1019, 1022]
# Disconnected section found, consisting of the following elements:
# buses: [126, 656, 1409]
# lines: [2066, 1163]
# Disconnected section found, consisting of the following elements:
# buses: [127, 152, 156, 170, 174, 182, 184, 186, 209, 238, 289, 294, 320, 360, 383, 471, 489, 521, 526, 533, 543, 628, 671, 672, 699, 720, 765, 768, 900, 903, 907, 910, 918, 921, 983, 993, 1068, 1158, 1263, 1289, 1296, 1299, 1312, 1314, 1315, 1317, 1322, 1339, 1341, 1344, 1355, 1357, 1358, 1390, 1392, 1396, 1397, 1410, 1432, 1440, 1442, 1563, 1567, 1574, 1576, 1584, 1590, 1594, 1602, 1611, 1634, 1670, 1687, 1704, 1706, 1746, 1863, 1952, 1955, 1960, 1975, 1998, 2130, 2133, 2166, 2189, 2204, 2220, 2223, 2233, 2256, 2351, 2453]
# lines: [3, 5, 13, 16, 18, 19, 22, 23, 28, 31, 34, 37, 40, 43, 44, 53, 55, 57, 59, 60, 64, 74, 76, 79, 80, 85, 86, 87, 93, 94, 113, 131, 136, 139, 154, 156, 159, 163, 165, 167, 178, 182, 184, 191, 194, 197, 198, 202, 206, 210, 216, 233, 1293, 1295, 1308, 1311, 1316, 1320, 1323, 1333, 1338, 1340, 1343, 1345, 1352, 1368, 1369, 1372, 1375, 1390, 1392, 1401, 1417, 1418, 1422, 1444, 1448, 1451, 1454, 1455, 1457, 1458, 1464, 445, 1470, 1471, 1477, 1481, 1489, 1493, 1495, 1500]
# Disconnected section found, consisting of the following elements:
# buses: [133, 135, 136, 140, 141, 142, 143, 210, 301, 302, 334, 388, 480, 481, 769, 887, 897, 911, 928, 936, 971, 972, 992, 1027, 1032, 1101, 1227, 1271, 1359, 1478, 1485, 1575, 1596, 1640, 1659, 1739, 2017, 2086, 2117, 2152, 2221, 2296, 2327, 2432, 2433, 2434, 2435, 2436, 2437, 2438, 2439, 2440, 2441, 2442, 2443]
# lines: [1413, 1419, 1421, 1297, 1298, 1299, 1300, 1425, 1431, 1305, 1306, 1307, 1435, 1309, 1436, 1312, 1440, 1314, 1445, 1318, 1321, 1329, 1460, 1335, 1337, 1465, 1339, 1341, 1472, 1474, 1348, 1478, 1480, 1353, 1355, 1485, 1358, 1363, 1366, 1367, 1496, 1370, 1371, 1373, 1374, 1379, 1383, 1384, 1389, 1395, 1397, 1399, 1400, 1407]
# Disconnected section found, consisting of the following elements:
# buses: [144, 145, 147]
# lines: [1241, 1242]
# Disconnected section found, consisting of the following elements:
# buses: [150, 175, 180, 274, 275, 395, 416]
# lines: [906, 779, 748, 922, 763, 765]
# Disconnected section found, consisting of the following elements:
# buses: [151, 160, 167, 191, 267, 277, 278, 1077, 2310, 2317]
# lines: [998, 999, 1000, 1001, 1002, 1003, 1004, 1006, 1007]
# Disconnected section found, consisting of the following elements:
# buses: [153, 775, 952, 953, 964, 979, 999, 1119, 1150, 1161, 1172, 1182, 1636, 1710]
# lines: [1760, 1734, 1801, 1707, 1710, 1680, 1744, 1715, 1811, 1812, 1686, 1784, 1787]
# Disconnected section found, consisting of the following elements:
# buses: [157, 162, 190, 283, 546, 566, 638, 886, 926, 1353, 1491, 1551, 1751, 2016, 2212, 2238, 2367]
# lines: [0, 223, 99, 199, 168, 42, 12, 14, 145, 50, 209, 117, 54, 126, 95, 63]
# Disconnected section found, consisting of the following elements:
# buses: [163, 555, 560, 598, 863, 946, 981, 994, 1000, 1004, 1007, 1010, 1021, 1023, 1036, 1039, 1076, 1118, 1212, 1404, 1474, 1673, 1925, 1944, 1985, 2177, 2398, 2399, 2400, 2401, 2402, 2403, 2404, 2405, 2406, 2407, 2408, 2409, 2410, 2411, 2412, 2413, 2414, 2415, 2416, 2417, 2418, 2419, 2420, 2421, 2422, 2423, 2424, 2425, 2426, 2427, 2428]
# lines: [772, 1671, 1928, 778, 1932, 911, 534, 1567, 1952, 1569, 1827, 549, 1575, 1576, 1579, 1580, 1836, 1582, 559, 1583, 1585, 1586, 1841, 1843, 1848, 1850, 1596, 962, 1602, 1604, 581, 582, 1605, 1864, 1611, 1616, 1622, 1623, 729, 1625, 1626, 1627, 1886, 1633, 1639, 1643, 1646, 879, 1647, 1650, 1651, 1652, 1910, 1659, 1916, 1661]
# Disconnected section found, consisting of the following elements:
# buses: [164, 165, 204, 303, 400, 402, 520, 527, 536, 537, 556, 563, 573, 615, 635, 639, 655, 686, 688, 737, 776, 871, 899, 938, 945, 947, 1019, 1029, 1153, 1283, 1380, 1685, 1753, 1947, 2018, 2243, 2391, 2454]
# lines: [1792, 1796, 6, 1798, 141, 1807, 20, 1684, 1685, 1688, 153, 25, 1817, 1695, 33, 1700, 1702, 39, 1704, 1705, 170, 1717, 1724, 62, 72, 73, 1740, 1741, 78, 1750, 98, 1776, 1780, 1782, 1783, 120, 1789]
# Disconnected section found, consisting of the following elements:
# buses: [172, 235, 286, 374, 579, 597, 636, 854, 1154, 1498, 1528, 1541, 1649, 1696, 1959, 1962, 1965, 1968, 1982, 1995, 2014, 2015, 2025, 2030, 2031, 2045, 2054, 2059, 2062, 2088, 2096, 2098, 2107, 2110, 2116, 2121, 2131, 2179, 2197, 2208, 2210, 2228, 2236, 2295, 2321, 2329, 2342, 2356, 2370]
# lines: [1411, 137, 1423, 400, 150, 1438, 1310, 1442, 1319, 2089, 2094, 2095, 1456, 2097, 2100, 2104, 2108, 2110, 1344, 2113, 66, 2114, 2115, 2117, 2118, 2123, 2125, 2128, 2130, 2131, 1365, 2133, 2135, 1880, 473, 2142, 2144, 1377, 1378, 1890, 2149, 1387, 2155, 1391, 116, 1404, 1917, 1919]
# Disconnected section found, consisting of the following elements:
# buses: [177, 272, 369, 454, 470, 487, 495, 518, 550, 599, 646, 758, 761, 762, 959, 1014, 1113, 1157, 1232, 1343, 1419, 1439, 1444, 1516, 1543, 1547, 1587, 1674, 1705, 1711, 1716, 1770, 1997, 2011, 2067, 2135, 2187, 2188, 2198, 2209, 2211, 2213, 2215, 2282, 2309]
# lines: [390, 391, 394, 396, 398, 399, 403, 407, 408, 285, 413, 414, 415, 295, 423, 427, 301, 437, 311, 312, 443, 702, 322, 327, 845, 463, 466, 341, 347, 350, 351, 478, 479, 355, 485, 359, 360, 504, 619, 370, 502, 248, 890, 381]
# Disconnected section found, consisting of the following elements:
# buses: [179, 218, 292, 415, 801, 883, 955, 975, 1082, 1159, 1164, 1203, 1219, 1220, 1270, 1352, 1368, 1378, 1388, 1600, 1750, 1811, 1839, 1856, 1861, 1906, 2065, 2080, 2149, 2264, 2345]
# lines: [900, 901, 902, 525, 782, 791, 924, 925, 798, 544, 545, 546, 550, 947, 707, 965, 586, 842, 972, 593, 721, 596, 983, 990, 863, 992, 871, 621, 885, 886]
# Disconnected section found, consisting of the following elements:
# buses: [185, 233, 450, 1178, 1655, 1666, 1700, 1831]
# lines: [256, 420, 293, 489, 490, 331, 283]
# Disconnected section found, consisting of the following elements:
# buses: [188, 211, 307, 319, 977, 1356, 2378]
# lines: [608, 865, 682, 554, 722, 949]
# Disconnected section found, consisting of the following elements:
# buses: [189, 649, 819, 923, 1135, 2150, 2255, 2350]
# lines: [450, 304, 435, 469, 438, 281, 378]
# Disconnected section found, consisting of the following elements:
# buses: [192, 654, 735]
# lines: [891, 631]
# Disconnected section found, consisting of the following elements:
# buses: [193, 194, 198, 224, 228, 234, 583, 584, 2275, 2277, 2301]
# lines: [2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035]
# Disconnected section found, consisting of the following elements:
# buses: [195, 197, 230, 295, 323, 326, 376, 390, 399, 442]
# lines: [71, 201, 107, 300, 110, 112, 368, 115, 121]
# Disconnected section found, consisting of the following elements:
# buses: [202, 217, 299, 332, 366, 439, 449, 457, 460, 468, 503, 504, 629, 717, 757, 767, 885, 1133, 1168, 1174, 1375, 1394, 1411, 1436, 1449, 1522, 1550, 1787, 1789, 1792, 1808, 1809, 1854, 1864, 1905, 1946, 2112, 2184, 2250, 2253, 2265, 2267, 2288, 2293, 2315]
# lines: [773, 905, 1806, 921, 540, 541, 542, 800, 547, 938, 944, 696, 824, 825, 571, 826, 573, 576, 580, 838, 970, 843, 590, 851, 724, 725, 601, 733, 734, 1757, 993, 610, 741, 743, 744, 1768, 747, 876, 623, 751, 880, 1779, 759, 1791]
# Disconnected section found, consisting of the following elements:
# buses: [203, 273, 305, 493, 517, 756, 803, 828, 2122, 2126]
# lines: [864, 803, 963, 808, 618, 861, 591, 560, 605]
# Disconnected section found, consisting of the following elements:
# buses: [207, 229]
# lines: [260]
# Disconnected section found, consisting of the following elements:
# buses: [212, 1040, 1044, 1045, 1051, 1067, 1141, 1183]
# lines: [832, 910, 703, 823, 857, 954, 831]
# Disconnected section found, consisting of the following elements:
# buses: [213, 223, 408, 417, 474, 482, 484, 1698]
# lines: [346, 432, 1521, 1530, 344, 250, 1502]
# Disconnected section found, consisting of the following elements:
# buses: [219, 409, 547, 1156, 1686, 1816, 2006, 2308]
# lines: [35, 195, 48, 49, 176, 26, 188]
# Disconnected section found, consisting of the following elements:
# buses: [222, 241, 304, 322, 405, 413, 423, 427, 447, 473, 531, 610, 742, 746, 779, 785, 787, 794, 1074, 1663, 2033, 2151, 2297]
# lines: [1920, 1925, 907, 528, 1825, 1955, 1828, 1838, 687, 569, 828, 1858, 837, 839, 1872, 1874, 866, 1892, 1895, 1897, 1901, 1906]
# Disconnected section found, consisting of the following elements:
# buses: [227, 266, 352, 387, 391, 419, 429, 488, 491, 500, 511, 697, 1138, 1510, 1535, 1586, 1592, 1784, 1991]
# lines: [1476, 1350, 1449, 1290, 1354, 1483, 1453, 1360, 1330, 1331, 1427, 1428, 1490, 1303, 1497, 1434, 1437, 1342]
# Disconnected section found, consisting of the following elements:
# buses: [231, 351, 1988, 2028, 2029, 2057, 2097, 2106]
# lines: [1922, 1891, 1930, 1899, 1869, 1879, 1944]
# Disconnected section found, consisting of the following elements:
# buses: [237, 567, 643, 657, 662, 781, 783, 800, 808, 817, 822, 1425, 1427]
# lines: [356, 393, 425, 395, 306, 434, 467, 342, 503, 441, 286, 255]
# Disconnected section found, consisting of the following elements:
# buses: [242, 835, 853]
# lines: [273, 267]
# Disconnected section found, consisting of the following elements:
# buses: [249, 373, 441, 483, 669, 698, 796, 845]
# lines: [97, 69, 10, 205, 29, 90, 61]
# Disconnected section found, consisting of the following elements:
# buses: [250, 290, 1204]
# lines: [657, 650]
# Disconnected section found, consisting of the following elements:
# buses: [253, 382, 956, 970, 1048, 1245, 1249, 1277, 1285, 1290, 1294, 1295, 1307, 1346, 1347, 1384, 1418, 1422, 1430, 1466, 1889, 1901, 1956, 1973, 1976, 1981, 2001, 2034]
# lines: [1536, 1, 1537, 1538, 1539, 1541, 1542, 1543, 1544, 1545, 1546, 1548, 1550, 1551, 1552, 1554, 1556, 1557, 935, 695, 572, 872, 749, 1531, 1533, 1534, 1535]
# Disconnected section found, consisting of the following elements:
# buses: [257, 434, 1202, 1909]
# lines: [1088, 1081, 1100]
# Disconnected section found, consisting of the following elements:
# buses: [259, 317, 667, 685, 723, 790, 806, 951, 1199, 1360, 1361, 1374, 1399, 1701, 2063, 2082, 2305, 2331, 2336]
# lines: [1995, 2156, 2157, 2158, 1967, 2159, 1969, 2160, 2161, 532, 2162, 2163, 2164, 2165, 1177, 2166, 1980, 1215]
# Disconnected section found, consisting of the following elements:
# buses: [264, 545, 576, 587, 619, 857, 858, 867, 942, 985, 1001, 1693, 1702, 1717, 1726, 1732, 1734, 1766, 1891, 1893, 1907, 1929, 1933, 1935, 1963, 1977, 1983, 1984, 1987, 1990, 2038, 2084, 2100, 2118, 2124, 2148, 2158, 2196]
# lines: [1664, 1668, 776, 909, 915, 1561, 1563, 1564, 1565, 1566, 1568, 929, 1572, 1573, 1703, 815, 816, 689, 943, 1598, 960, 1607, 1612, 719, 1624, 604, 1628, 1630, 737, 1634, 1637, 1644, 877, 625, 1649, 1656, 1657]
# Disconnected section found, consisting of the following elements:
# buses: [280, 422, 631, 1284, 1793, 2136, 2337, 2360]
# lines: [196, 166, 204, 45, 47, 144, 208]
# Disconnected section found, consisting of the following elements:
# buses: [282, 418, 432, 443, 754, 755, 939, 2270]
# lines: [416, 323, 366, 402, 436, 249, 253]
# Disconnected section found, consisting of the following elements:
# buses: [285, 861, 1022, 1031, 1034, 1035, 1069, 1616, 1833, 1922, 1923, 1942, 2338, 2355]
# lines: [1223, 1192, 1193, 1132, 1198, 1232, 1234, 1203, 1141, 1144, 1178, 1180, 1181]
# Disconnected section found, consisting of the following elements:
# buses: [296, 313, 315, 410, 507, 519, 551, 607, 882, 931, 954, 961, 989, 1105, 1110, 1120, 1149, 1193, 1201, 1316, 1348, 1349, 1379, 1431, 1475, 1561, 2040, 2068]
# lines: [130, 133, 134, 517, 521, 11, 140, 143, 148, 27, 157, 172, 51, 180, 185, 193, 67, 77, 214, 218, 92, 226, 101, 104, 1257, 109, 509]
# Disconnected section found, consisting of the following elements:
# buses: [309, 1461, 1533]
# lines: [382, 310]
# Disconnected section found, consisting of the following elements:
# buses: [310, 348]
# lines: [892]
# Disconnected section found, consisting of the following elements:
# buses: [314, 353, 355, 394, 444, 459, 463, 465, 748, 797, 823, 829, 832, 841, 860, 864, 875, 896, 1558, 1559, 1570, 1719, 1744, 1747, 1759, 1764, 1900, 1930, 1969, 2137, 2138, 2143, 2144, 2161, 2384]
# lines: [1154, 1160, 1161, 1166, 1054, 1055, 1056, 1057, 1183, 1059, 1186, 1061, 1063, 1065, 1068, 1197, 1072, 1076, 1078, 1208, 1086, 1216, 1091, 1225, 1099, 1108, 1117, 1246, 1119, 1124, 1125, 1126, 1130, 1147]
# Disconnected section found, consisting of the following elements:
# buses: [325, 1452, 1721]
# lines: [652, 524]
# Disconnected section found, consisting of the following elements:
# buses: [328, 377, 508, 534, 663, 991, 1336, 1376, 1415, 1566, 1684, 1824, 2170]
# lines: [1024, 1025, 1027, 1028, 1032, 1034, 1036, 979, 1017, 1020, 1021, 1023]
# Disconnected section found, consisting of the following elements:
# buses: [329, 485, 496, 522, 1228, 1255, 1260]
# lines: [718, 1047, 1048, 889, 1051, 1052]
# Disconnected section found, consisting of the following elements:
# buses: [330, 577, 1980, 2323, 2340, 2344, 2358]
# lines: [1039, 1040, 1042, 1045, 1049, 1050]
# Disconnected section found, consisting of the following elements:
# buses: [336, 851]
# lines: [674]
# Disconnected section found, consisting of the following elements:
# buses: [337, 343, 361, 381]
# lines: [1008, 1009, 1010]
# Disconnected section found, consisting of the following elements:
# buses: [350, 354, 512, 751, 772, 893, 948, 995, 1009, 1140, 1515, 1632, 1738, 1860, 2109, 2147, 2156, 2159, 2169, 2199, 2369]
# lines: [771, 533, 919, 553, 809, 940, 429, 691, 566, 568, 698, 959, 833, 961, 579, 980, 860, 868, 874, 506]
# Disconnected section found, consisting of the following elements:
# buses: [358, 379]
# lines: [681]
# Disconnected section found, consisting of the following elements:
# buses: [363, 1197, 1405, 1680, 1774, 1780, 1822, 1850, 2222]
# lines: [1730, 612, 1800, 1712, 881, 530, 1745, 1716]
# Disconnected section found, consisting of the following elements:
# buses: [365, 1218]
# lines: [1961]
# Disconnected section found, consisting of the following elements:
# buses: [372, 392, 412, 428, 436, 464, 509, 593, 678, 707, 789, 1460, 1472, 1509, 1513, 1536, 1578, 1589, 1606, 2119, 2125, 2183, 2193, 2207, 2339, 2353]
# lines: [1666, 1672, 1674, 1675, 1676, 1560, 1562, 1570, 1574, 1581, 1587, 1589, 1591, 1595, 1601, 1606, 1609, 1610, 1613, 1614, 1619, 1640, 1641, 1642, 1662]
# Disconnected section found, consisting of the following elements:
# buses: [384, 535, 1242, 1286, 1421, 2195]
# lines: [4, 70, 102, 38, 75]
# Disconnected section found, consisting of the following elements:
# buses: [397, 492, 497, 963, 990, 1013, 1107, 1179, 1209, 1273, 1324, 1371]
# lines: [1380, 1349, 1382, 1446, 1289, 1325, 1357, 1327, 1301, 1302, 1334]
# Disconnected section found, consisting of the following elements:
# buses: [403, 440, 513, 525, 600, 601, 677, 703, 719, 726, 727, 740, 1994, 2023, 2026, 2027, 2052, 2087, 2095, 2105, 2392, 2393, 2394, 2395, 2396, 2397]
# lines: [132, 138, 409, 32, 291, 1315, 175, 1466, 449, 451, 330, 207, 464, 338, 1362, 84, 1494, 345, 91, 225, 358, 492, 373, 1403, 383]
# Disconnected section found, consisting of the following elements:
# buses: [406, 424]
# lines: [654]
# Disconnected section found, consisting of the following elements:
# buses: [420, 430, 549, 594, 623, 713, 739, 798, 809, 847, 849, 862, 874, 891, 916, 933, 962, 978, 998, 1006, 1011, 1025, 1037, 1043, 1085, 1088, 1098, 1136, 1192, 1195, 1222, 1224, 1233, 1252, 1272, 1401, 1468, 1480, 1501, 1773, 1823, 1838, 1841, 1871, 1875, 1986, 2205, 2206, 2300, 2303, 2343]
# lines: [1921, 1926, 1929, 1931, 1934, 1938, 1943, 1945, 1946, 1821, 1823, 1824, 1951, 1826, 1956, 1830, 1831, 1832, 1959, 1834, 1835, 1842, 1844, 1846, 1852, 1855, 1859, 1860, 2116, 1862, 2120, 1866, 1873, 2129, 1876, 1877, 1878, 1884, 1885, 1887, 1888, 1894, 1896, 2153, 1898, 1902, 1903, 1907, 1912, 1918]
# Disconnected section found, consisting of the following elements:
# buses: [431, 929, 943, 944, 1173, 2354]
# lines: [1221, 1169, 1170, 1172, 1239]
# Disconnected section found, consisting of the following elements:
# buses: [433, 1548, 2041, 2071]
# lines: [363, 405, 495]
# Disconnected section found, consisting of the following elements:
# buses: [451, 630, 830, 1527, 2311, 2376]
# lines: [942, 527, 849, 754, 856]
# Disconnected section found, consisting of the following elements:
# buses: [453, 458, 472, 475, 506, 888, 1484, 2242]
# lines: [129, 9, 106, 169, 114, 122, 219]
# Disconnected section found, consisting of the following elements:
# buses: [455, 1280, 1335]
# lines: [706, 611]
# Disconnected section found, consisting of the following elements:
# buses: [456, 1428, 1434, 1437, 1477, 1482, 2053]
# lines: [264, 235, 236, 365, 238, 278]
# Disconnected section found, consisting of the following elements:
# buses: [461, 1064, 1148, 1662, 1931]
# lines: [1280, 1288, 1284, 1286]
# Disconnected section found, consisting of the following elements:
# buses: [466, 603, 715, 802, 1152, 1337]
# lines: [512, 514, 515, 516, 510]
# Disconnected section found, consisting of the following elements:
# buses: [498, 514, 743, 752, 791, 833, 844, 880, 941, 986, 1018, 1256, 1451, 1723, 1730]
# lines: [1856, 1857, 1829, 1863, 1900, 1870, 1839, 1840, 1904, 1908, 1913, 1882, 1851, 1948]
# Disconnected section found, consisting of the following elements:
# buses: [510, 2090, 2099, 2102, 2108, 2113, 2127, 2132, 2134, 2139, 2146, 2168]
# lines: [672, 643, 644, 676, 647, 656, 658, 659, 628, 634, 668]
# Disconnected section found, consisting of the following elements:
# buses: [523, 529, 548, 552, 574, 591, 596, 606, 609, 622, 625, 651, 665, 675, 689, 694, 711, 712, 725, 807, 821, 872, 902, 913, 935, 1102, 1106, 1274, 1319, 1320, 1332, 1367, 1664, 1669, 1760, 1776, 1777, 1897, 1898, 1937, 2019, 2046, 2055, 2074, 2083, 2085, 2202, 2330, 2371]
# lines: [1408, 1409, 1410, 1412, 1415, 1416, 1292, 1420, 1294, 1296, 1426, 1429, 1430, 1433, 1439, 1313, 1441, 1443, 1317, 1322, 1450, 1452, 1459, 1332, 1461, 1462, 1463, 1336, 1467, 1468, 1475, 1351, 1482, 1484, 1487, 1488, 1361, 1492, 1498, 1381, 1385, 1386, 1393, 1394, 1396, 1398, 1402, 1405]
# Disconnected section found, consisting of the following elements:
# buses: [530, 544, 585, 1943]
# lines: [242, 275, 277]
# Disconnected section found, consisting of the following elements:
# buses: [558, 679, 690, 728, 1071, 1129, 1191, 1508, 1532, 2140, 2326]
# lines: [96, 192, 135, 46, 212, 24, 220, 222, 190, 127]
# Disconnected section found, consisting of the following elements:
# buses: [561, 693, 1103]
# lines: [186, 15]
# Disconnected section found, consisting of the following elements:
# buses: [565, 569, 570, 1072, 2051]
# lines: [664, 666, 675, 645]
# Disconnected section found, consisting of the following elements:
# buses: [571, 627, 1752]
# lines: [1739, 1749]
# Disconnected section found, consisting of the following elements:
# buses: [578, 1189]
# lines: [648]
# Disconnected section found, consisting of the following elements:
# buses: [581, 588, 846, 1056, 1254, 1278, 1297, 1309, 1459, 2381]
# lines: [2057, 2060, 2062, 2063, 2068, 2069, 2071, 2074, 2075]
# Disconnected section found, consisting of the following elements:
# buses: [590, 865, 890, 922, 937, 1186, 1713, 1715, 1741, 1757, 1772, 1797, 1812, 1820, 1847, 2064, 2066, 2093, 2115]
# lines: [769, 2146, 742, 2119, 936, 2107, 2152, 1965, 561, 1522, 1905, 1940, 2134, 920, 1914, 699, 2109, 927]
# Disconnected section found, consisting of the following elements:
# buses: [592, 877, 895, 1257, 1279, 1306, 1996]
# lines: [100, 7, 173, 241, 215, 217]
# Disconnected section found, consisting of the following elements:
# buses: [611, 1414, 1517, 1703, 1707, 1709, 1712, 1714, 1742, 1786, 1849, 1899]
# lines: [386, 326, 1511, 1512, 1513, 1520, 1525, 1528, 282, 348, 1503]
# Disconnected section found, consisting of the following elements:
# buses: [612, 659, 965, 980, 1003, 1024, 1046, 1047, 1060, 1084, 1092, 1124, 1125, 1139, 1181, 2141]
# lines: [288, 321, 455, 297, 329, 431, 305, 499, 308, 245, 501, 247, 280, 442, 317]
# Disconnected section found, consisting of the following elements:
# buses: [616, 618, 632, 641, 645, 653, 666, 681, 826, 834, 1330, 1331]
# lines: [2080, 2081, 2083, 2085, 2086, 2099, 1785, 1755, 2076, 2078, 2079]
# Disconnected section found, consisting of the following elements:
# buses: [634, 734, 920, 966, 982, 1005, 1026, 1180, 1327, 1467, 2154, 2230, 2232, 2246, 2258, 2316]
# lines: [1889, 614, 875, 781, 686, 848, 817, 595, 883, 1909, 950, 1942, 764, 701, 1950]
# Disconnected section found, consisting of the following elements:
# buses: [668, 1599, 1601]
# lines: [426, 364]
# Disconnected section found, consisting of the following elements:
# buses: [670, 733]
# lines: [626]
# Disconnected section found, consisting of the following elements:
# buses: [695, 702, 2292]
# lines: [276, 263]
# Disconnected section found, consisting of the following elements:
# buses: [718, 731, 1080, 2078, 2128, 2279, 2286, 2306]
# lines: [228, 457, 302, 372, 468, 252, 477]
# Disconnected section found, consisting of the following elements:
# buses: [721, 763, 773, 799, 1147, 1163, 1338, 1479, 1524, 1539]
# lines: [481, 447, 108, 334, 494, 496, 401, 307, 287]
# Disconnected section found, consisting of the following elements:
# buses: [738, 777, 1381, 1389, 2291]
# lines: [56, 17, 83, 149]
# Disconnected section found, consisting of the following elements:
# buses: [747, 811]
# lines: [677]
# Disconnected section found, consisting of the following elements:
# buses: [750, 2239, 2334]
# lines: [1152, 1189]
# Disconnected section found, consisting of the following elements:
# buses: [759, 771, 782, 804, 1677, 2129]
# lines: [65, 146, 118, 151, 152]
# Disconnected section found, consisting of the following elements:
# buses: [764, 873, 889, 894, 915, 932, 1650, 1727, 1748, 1762, 1768, 1778, 1807, 1829, 1835, 2269, 2322, 2362]
# lines: [1504, 1505, 1506, 1507, 1508, 1510, 8, 298, 1514, 1515, 1516, 1518, 1519, 1523, 1527, 1529, 123]
# Disconnected section found, consisting of the following elements:
# buses: [770, 836]
# lines: [262]
# Disconnected section found, consisting of the following elements:
# buses: [778, 1978]
# lines: [841]
# Disconnected section found, consisting of the following elements:
# buses: [784, 1661, 2266]
# lines: [234, 1837]
# Disconnected section found, consisting of the following elements:
# buses: [795, 1216, 1217, 1526]
# lines: [1096, 1131, 1109]
# Disconnected section found, consisting of the following elements:
# buses: [810, 974, 1050, 1053, 1055, 1167, 1171, 2035]
# lines: [384, 453, 486, 296, 340, 349, 319]
# Disconnected section found, consisting of the following elements:
# buses: [820, 1059, 1065, 1094, 1775, 1842, 1852, 1999, 2231, 2375]
# lines: [1089, 1102, 1071, 1079, 1113, 1082, 1115, 1053, 1118]
# Disconnected section found, consisting of the following elements:
# buses: [831, 850, 856, 1927, 2145]
# lines: [266, 269, 229, 279]
# Disconnected section found, consisting of the following elements:
# buses: [838, 1481, 1488, 1489, 1494, 1529, 1540, 1553, 1603]
# lines: [324, 389, 294, 361, 303, 244, 475, 316]
# Disconnected section found, consisting of the following elements:
# buses: [866, 1121]
# lines: [539]
# Disconnected section found, consisting of the following elements:
# buses: [868, 884]
# lines: [314]
# Disconnected section found, consisting of the following elements:
# buses: [869, 1261, 2003, 2010, 2012, 2013, 2032, 2042, 2047, 2091]
# lines: [261, 230, 231, 232, 265, 268, 239, 271, 274]
# Disconnected section found, consisting of the following elements:
# buses: [870, 1953, 1954, 1957, 1974, 1992]
# lines: [418, 493, 404, 412, 380]
# Disconnected section found, consisting of the following elements:
# buses: [876, 1196]
# lines: [780]
# Disconnected section found, consisting of the following elements:
# buses: [898, 904, 957, 1008, 2430, 2431]
# lines: [1697, 1698, 1773, 1682, 1815]
# Disconnected section found, consisting of the following elements:
# buses: [901, 1185]
# lines: [1229]
# Disconnected section found, consisting of the following elements:
# buses: [927]
# Disconnected section found, consisting of the following elements:
# buses: [934, 1016]
# lines: [946]
# Disconnected section found, consisting of the following elements:
# buses: [973, 996]
# lines: [723]
# Disconnected section found, consisting of the following elements:
# buses: [1028, 1487, 1843, 1896, 2114, 2234, 2262, 2285, 2319]
# lines: [289, 488, 299, 337, 498, 246, 343, 505]
# Disconnected section found, consisting of the following elements:
# buses: [1030, 1033, 1052, 1054]
# lines: [487, 430, 471]
# Disconnected section found, consisting of the following elements:
# buses: [1038, 1066, 1230]
# lines: [2101, 967]
# Disconnected section found, consisting of the following elements:
# buses: [1042, 1235, 1369, 1514, 1581]
# lines: [1376, 1491, 1356, 1469]
# Disconnected section found, consisting of the following elements:
# buses: [1057, 1143, 1187]
# lines: [1037, 1038]
# Disconnected section found, consisting of the following elements:
# buses: [1058, 1100]
# lines: [665]
# Disconnected section found, consisting of the following elements:
# buses: [1062, 1070, 1083, 1086, 1090, 1093, 1117, 1126, 1128, 1225, 1226, 1250, 1580, 1588, 1609, 1610, 1612, 1614, 1625, 1639, 1641, 1643, 1644, 1645, 1675, 1802]
# lines: [1923, 1927, 1935, 1936, 1937, 1941, 1947, 1820, 1949, 1953, 1954, 1957, 1833, 1964, 1845, 1847, 1854, 1865, 1867, 1868, 1871, 1875, 1893, 1911, 1915]
# Disconnected section found, consisting of the following elements:
# buses: [1087, 1635, 1637, 1642, 1672, 1676, 1681, 1958, 1993, 2000, 2002, 2009, 2020, 2070, 2079, 2274, 2284, 2298, 2299, 2318]
# lines: [1540, 1547, 1549, 784, 529, 785, 1553, 1555, 1558, 1559, 818, 700, 592, 598, 740, 869, 757, 1532, 767]
# Disconnected section found, consisting of the following elements:
# buses: [1111, 1251, 1259, 1262]
# lines: [1209, 1138, 1133]
# Disconnected section found, consisting of the following elements:
# buses: [1132, 1162, 1176]
# lines: [352, 292]
# Disconnected section found, consisting of the following elements:
# buses: [1145, 1194, 1198, 1229, 1231, 1234, 1264, 1269, 1313, 1329, 1345, 1363, 1365, 1913, 1966, 1979, 2069]
# lines: [2178, 2180, 2184, 2185, 2186, 2191, 2192, 2193, 2204, 2197, 2199, 2169, 2203, 2172, 2173, 2174]
# Disconnected section found, consisting of the following elements:
# buses: [1146, 1443, 1555, 1562, 1630, 2007, 2104]
# lines: [128, 200, 41, 88, 187, 158]
# Disconnected section found, consisting of the following elements:
# buses: [1166, 1671, 1690, 2163]
# lines: [1200, 1214, 1151]
# Disconnected section found, consisting of the following elements:
# buses: [1188, 1326]
# lines: [788]
# Disconnected section found, consisting of the following elements:
# buses: [1207, 1848]
# lines: [641]
# Disconnected section found, consisting of the following elements:
# buses: [1223, 2241, 2245, 2325]
# lines: [392, 385, 456]
# Disconnected section found, consisting of the following elements:
# buses: [1266, 1653, 1660]
# lines: [1770, 1775]
# Disconnected section found, consisting of the following elements:
# buses: [1288, 1293, 1305, 1328, 1827, 1880, 1918, 1924]
# lines: [1861, 1933, 1939, 1849, 1883, 1853, 1822]
# Disconnected section found, consisting of the following elements:
# buses: [1298, 1423, 1708, 1743, 2200]
# lines: [1960, 1881, 1962, 1963]
# Disconnected section found, consisting of the following elements:
# buses: [1300, 1304]
# lines: [476]
# Disconnected section found, consisting of the following elements:
# buses: [1323, 1500, 1665, 1754, 2314]
# lines: [58, 211, 125, 227]
# Disconnected section found, consisting of the following elements:
# buses: [1366, 1457, 1470, 1507, 1512, 1577, 1887]
# lines: [1479, 1326, 1359, 1424, 1432, 1406]
# Disconnected section found, consisting of the following elements:
# buses: [1385, 1492, 2237, 2248, 2252, 2268, 2281, 2289, 2294, 2307, 2333, 2349, 2389]
# lines: [480, 419, 460, 461, 462, 1328, 406, 374, 313, 444, 411, 284]
# Disconnected section found, consisting of the following elements:
# buses: [1387]
# Disconnected section found, consisting of the following elements:
# buses: [1455, 1456, 1476, 1493, 1496, 1497, 1745, 1767, 1806, 1828, 1890, 1902, 2157, 2229]
# lines: [1729, 1795, 2148, 2121, 2092, 2093, 2126, 2127, 2096, 2143, 2106, 1758, 2111]
# Disconnected section found, consisting of the following elements:
# buses: [1462, 1502]
# lines: [1005]
# Disconnected section found, consisting of the following elements:
# buses: [1505, 1654, 1771, 2272]
# lines: [1251, 1270, 1263]
# Disconnected section found, consisting of the following elements:
# buses: [1542, 2373]
# lines: [807]
# Disconnected section found, consisting of the following elements:
# buses: [1618, 1619, 1646, 1656]
# lines: [642, 661, 638]
# Disconnected section found, consisting of the following elements:
# buses: [1631]
# Disconnected section found, consisting of the following elements:
# buses: [1689, 1695]
# lines: [895]
# Disconnected section found, consisting of the following elements:
# buses: [1756, 1794, 1878, 1883, 1911, 1917, 1919, 1921, 1941, 1949]
# lines: [448, 417, 259, 452, 328, 458, 367, 377, 315]
# Disconnected section found, consisting of the following elements:
# buses: [1803, 1813, 1857]
# lines: [237, 270]
# Disconnected section found, consisting of the following elements:
# buses: [1805, 1814, 1855, 1858, 1859, 1873, 1904, 1940, 2444, 2445, 2446, 2447, 2448, 2449, 2450, 2451, 2452]
# lines: [1473, 1347, 2021, 1414, 1447, 2022, 2023, 2024, 1291, 1388, 2025, 1486, 1808, 1364, 1304, 1499]
# Disconnected section found, consisting of the following elements:
# buses: [1830]
# Disconnected section found, consisting of the following elements:
# buses: [1832, 1868]
# lines: [898]
# Disconnected section found, consisting of the following elements:
# buses: [1886, 2390]
# lines: [577]
# Disconnected section found, consisting of the following elements:
# buses: [1910, 1951, 2173]
# lines: [987, 933]
# Disconnected section found, consisting of the following elements:
# buses: [1970, 2060]
# lines: [594]
# Disconnected section found, consisting of the following elements:
# buses: [2048, 2123]
# lines: [1958]
# Disconnected section found, consisting of the following elements:
# buses: [2056, 2061, 2094]
# lines: [497, 357]
# Disconnected section found, consisting of the following elements:
# buses: [2072]
# Disconnected section found, consisting of the following elements:
# buses: [2348]
# Disconnected section found, consisting of the following elements:
# buses: [2374, 2380]
# lines: [1093]
# Disconnected section found, consisting of the following elements:
# buses: [2377]
#
# SUMMARY: 4681 disconnected element(s) found.
#
#  --------
#
# Checking for impedance values close to zero...
#
# line 1061: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1107: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1202: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1242: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2011: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2067: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2137: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2207: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2208: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2210: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2211: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2224: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2225: r_ohm <= 0.001 or x_ohm <= 0.001
# line 2227: r_ohm <= 0.001 or x_ohm <= 0.001
#
# SUMMARY: 14 element(s) with impedance values close to zero found.
#
#  --------
#
# _____________ END OF PANDAPOWER DIAGNOSTIC _____________
# Number of disconnected sections: 226
# Closest section: {1266, 1660, 1653}, closest bus: 1653, closest main_bus: 1718, min_distance: 0.00012071491209461047
# Connected bus 1653 to 1718 with New Line 1 Alimentador 675
# Number of disconnected sections: 225
# Closest section: {1690, 2163, 1166, 1671}, closest bus: 1671, closest main_bus: 2164, min_distance: 0.0002693124950771515
# Connected bus 1671 to 2164 with New Line 2 Alimentador 675
# Number of disconnected sections: 224
# Closest section: {1387}, closest bus: 1387, closest main_bus: 1382, min_distance: 0.0002785937005789811
# Connected bus 1387 to 1382 with New Line 3 Alimentador 675
# Number of disconnected sections: 223
# Closest section: {1446, 967, 1416, 1433, 1420, 1424, 1238, 57, 701}, closest bus: 57, closest main_bus: 1387, min_distance: 0.0002627677681880076
# Connected bus 57 to 1387 with New Line 4 Alimentador 675
# Number of disconnected sections: 222
# Closest section: {2377}, closest bus: 2377, closest main_bus: 1446, min_distance: 0.00011776132641621979
# Connected bus 2377 to 1446 with New Line 5 Alimentador 675
# Number of disconnected sections: 221
# Closest section: {1216, 1217, 795, 1526}, closest bus: 1216, closest main_bus: 2377, min_distance: 0.00010866609407027126
# Connected bus 1216 to 2377 with New Line 6 Alimentador 675
# Number of disconnected sections: 220
# Closest section: {1059, 1094, 2375, 1065, 1775, 1999, 1842, 820, 2231, 1852}, closest bus: 2375, closest main_bus: 795, min_distance: 0.00016296502692205594
# Connected bus 2375 to 795 with New Line 7 Alimentador 675
# Number of disconnected sections: 219
# Closest section: {1830}, closest bus: 1830, closest main_bus: 1216, min_distance: 0.00018400157608164174
# Connected bus 1830 to 1216 with New Line 8 Alimentador 675
# Number of disconnected sections: 218
# Closest section: {1281, 1537, 2182, 1546, 780, 788, 21, 22, 1945, 1964, 559, 178, 1971, 311, 1210, 827, 1213, 580, 1221, 1605, 842, 1615, 2259, 344, 1240, 1114, 1246, 744, 745, 1137, 626, 505}, closest bus: 1246, closest main_bus: 2377, min_distance: 0.00025232782248213166
# Connected bus 1246 to 2377 with New Line 9 Alimentador 675
# Number of disconnected sections: 217
# Closest section: {1241, 7}, closest bus: 1241, closest main_bus: 22, min_distance: 1.8578482173480312e-05
# Connected bus 1241 to 22 with New Line 10 Alimentador 675
# Number of disconnected sections: 216
# Closest section: {674, 83}, closest bus: 674, closest main_bus: 21, min_distance: 1.912694434705227e-05
# Connected bus 674 to 21 with New Line 11 Alimentador 675
# Number of disconnected sections: 215
# Closest section: {1970, 2060}, closest bus: 2060, closest main_bus: 1971, min_distance: 7.404383836286063e-05
# Connected bus 2060 to 1971 with New Line 12 Alimentador 675
# Number of disconnected sections: 214
# ...
# Number of disconnected sections: 69
# Closest section: {1070, 1310}, closest bus: 1070, closest main_bus: 1306, min_distance: 9.30260716128356e-05
# Connected bus 1070 to 1306 with New Line 69 Alimentador 678
# Number of disconnected sections: 68
# Closest section: {227, 411}, closest bus: 227, closest main_bus: 413, min_distance: 0.00010044481071837174
# Connected bus 227 to 413 with New Line 70 Alimentador 678
# Number of disconnected sections: 67
# Closest section: {85, 86}, closest bus: 85, closest main_bus: 227, min_distance: 9.329276498920065e-05
# Connected bus 85 to 227 with New Line 71 Alimentador 678
# Number of disconnected sections: 66
# Closest section: {587, 693, 686}, closest bus: 686, closest main_bus: 586, min_distance: 0.00044810538938109797
# Connected bus 686 to 586 with New Line 72 Alimentador 678
# Number of disconnected sections: 65
# Closest section: {1152, 520, 778, 528, 1169, 788, 246}, closest bus: 246, closest main_bus: 252, min_distance: 0.00046171230220282963
# Connected bus 246 to 252 with New Line 73 Alimentador 678
# Number of disconnected sections: 64
# Closest section: {841, 773}, closest bus: 841, closest main_bus: 788, min_distance: 0.0003832858463295398
# Connected bus 841 to 788 with New Line 74 Alimentador 678
# Number of disconnected sections: 63
# Closest section: {1220, 1350, 230, 646, 1195, 1035, 206, 1231, 15, 240, 848, 179, 822, 249, 346, 1339, 25}, closest bus: 848, closest main_bus: 1376, min_distance: 0.0005004220718583642
# Connected bus 848 to 1376 with New Line 75 Alimentador 678
# Number of disconnected sections: 62
# Closest section: {1, 18, 1329}, closest bus: 1329, closest main_bus: 15, min_distance: 6.985613788906413e-05
# Connected bus 1329 to 15 with New Line 76 Alimentador 678
# Number of disconnected sections: 61
# Closest section: {433, 814}, closest bus: 433, closest main_bus: 822, min_distance: 8.208343315602528e-05
# Connected bus 433 to 822 with New Line 77 Alimentador 678
# Number of disconnected sections: 60
# Closest section: {160, 14}, closest bus: 14, closest main_bus: 15, min_distance: 0.00014156924100776114
# Connected bus 14 to 15 with New Line 78 Alimentador 678
# Number of disconnected sections: 59
# Closest section: {136, 106, 31}, closest bus: 106, closest main_bus: 15, min_distance: 0.00019357127886190402
# Connected bus 106 to 15 with New Line 79 Alimentador 678
# Number of disconnected sections: 58
# Closest section: {1384, 1034}, closest bus: 1384, closest main_bus: 1035, min_distance: 0.0003078447985578561
# Connected bus 1384 to 1035 with New Line 80 Alimentador 678
# Number of disconnected sections: 57
# Closest section: {1377, 1378, 330, 331, 338}, closest bus: 330, closest main_bus: 31, min_distance: 0.00035525378253715984
# Connected bus 330 to 31 with New Line 81 Alimentador 678
# Number of disconnected sections: 56
# Closest section: {33, 519}, closest bus: 33, closest main_bus: 1378, min_distance: 1.690000000346222e-05
# Connected bus 33 to 1378 with New Line 82 Alimentador 678
# Number of disconnected sections: 55
# Closest section: {34, 1379, 342}, closest bus: 1379, closest main_bus: 519, min_distance: 1.9736767717885624e-05
# Connected bus 1379 to 519 with New Line 83 Alimentador 678
# Number of disconnected sections: 54
# Closest section: {187, 131, 171}, closest bus: 131, closest main_bus: 1195, min_distance: 0.00036931435120096716
# Connected bus 131 to 1195 with New Line 84 Alimentador 678
# Number of disconnected sections: 53
# Closest section: {188, 164, 286, 511}, closest bus: 188, closest main_bus: 131, min_distance: 8.11379689156049e-05
# Connected bus 188 to 131 with New Line 85 Alimentador 678
# Number of disconnected sections: 52
# Closest section: {1380, 623}, closest bus: 1380, closest main_bus: 511, min_distance: 2.5515681451131972e-05
# Connected bus 1380 to 511 with New Line 86 Alimentador 678
# Number of disconnected sections: 51
# Closest section: {611, 13}, closest bus: 611, closest main_bus: 1380, min_distance: 2.5185710237182553e-05
# Connected bus 611 to 1380 with New Line 87 Alimentador 678
# Number of disconnected sections: 50
# Closest section: {6, 777, 267, 781, 147, 405, 661, 21, 432, 1331, 455, 461, 469, 341, 477, 355, 491, 241, 627, 244, 631, 637, 639}, closest bus: 267, closest main_bus: 25, min_distance: 0.0003797393843166194
# Connected bus 267 to 25 with New Line 88 Alimentador 678
# Number of disconnected sections: 49
# Closest section: {795, 1179, 1189}, closest bus: 1189, closest main_bus: 777, min_distance: 0.00017353722943592442
# Connected bus 1189 to 777 with New Line 89 Alimentador 678
# Number of disconnected sections: 48
# Closest section: {130, 112, 305, 114, 20, 125, 220, 349, 126}, closest bus: 130, closest main_bus: 1331, min_distance: 0.00018218641551643672
# Connected bus 130 to 1331 with New Line 90 Alimentador 678
# Number of disconnected sections: 47
# Closest section: {304, 1096}, closest bus: 1096, closest main_bus: 305, min_distance: 0.0001345157239912313
# Connected bus 1096 to 305 with New Line 91 Alimentador 678
# Number of disconnected sections: 46
# Closest section: {633, 642, 619, 87}, closest bus: 87, closest main_bus: 639, min_distance: 0.0001972291307085932
# Connected bus 87 to 639 with New Line 92 Alimentador 678
# Number of disconnected sections: 45
# Closest section: {444, 229, 358, 399}, closest bus: 229, closest main_bus: 20, min_distance: 0.000211967662631247
# Connected bus 229 to 20 with New Line 93 Alimentador 678
# Number of disconnected sections: 44
# Closest section: {238, 254}, closest bus: 254, closest main_bus: 240, min_distance: 0.0004233195129060984
# Connected bus 254 to 240 with New Line 94 Alimentador 678
# Number of disconnected sections: 43
# Closest section: {768, 903, 904, 521, 907, 909, 911, 912, 1041, 530, 918, 921, 931, 933, 934, 552, 680, 683, 940, 945, 820, 949, 709, 712, 713, 714, 984, 985, 986, 729, 730, 992, 100, 870, 111, 884, 756, 887, 504, 889, 890, 763}, closest bus: 100, closest main_bus: 519, min_distance: 0.0004901698175102123
# Connected bus 100 to 519 with New Line 95 Alimentador 678
# Number of disconnected sections: 42
# Closest section: {951, 935}, closest bus: 951, closest main_bus: 940, min_distance: 0.00013778824333297992
# Connected bus 951 to 940 with New Line 96 Alimentador 678
# Number of disconnected sections: 41
# Closest section: {833, 819, 799}, closest bus: 833, closest main_bus: 779, min_distance: 0.0005441434829135828
# Connected bus 833 to 779 with New Line 97 Alimentador 678
# Number of disconnected sections: 40
# Closest section: {818, 821}, closest bus: 821, closest main_bus: 819, min_distance: 9.084459257298711e-05
# Connected bus 821 to 819 with New Line 98 Alimentador 678
# Number of disconnected sections: 39
# Closest section: {354, 165}, closest bus: 165, closest main_bus: 364, min_distance: 0.0006708192006729438
# Connected bus 165 to 364 with New Line 99 Alimentador 678
# Number of disconnected sections: 38
# Closest section: {345, 258, 699, 380}, closest bus: 345, closest main_bus: 455, min_distance: 0.0007069607768493252
# Connected bus 345 to 455 with New Line 100 Alimentador 678
# Number of disconnected sections: 37
# Closest section: {719, 636, 583, 271}, closest bus: 271, closest main_bus: 699, min_distance: 0.0003248126229073714
# Connected bus 271 to 699 with New Line 101 Alimentador 678
# Number of disconnected sections: 36
# Closest section: {846, 412, 430, 431}, closest bus: 412, closest main_bus: 583, min_distance: 0.0008901944281995069
# Connected bus 412 to 583 with New Line 102 Alimentador 678
# Number of disconnected sections: 35
# Closest section: {289, 866, 708, 37, 999, 1328, 688, 817, 275, 629, 982, 279, 697, 314, 285, 991}, closest bus: 866, closest main_bus: 846, min_distance: 0.0009031915854318597
# Connected bus 866 to 846 with New Line 103 Alimentador 678
# Number of disconnected sections: 34
# Closest section: {710, 43, 178, 502, 635}, closest bus: 178, closest main_bus: 314, min_distance: 9.699814430427374e-05
# Connected bus 178 to 314 with New Line 104 Alimentador 678
# Number of disconnected sections: 33
# Closest section: {1025, 1284, 917, 791, 281, 1063, 939, 176, 1338, 189, 190, 1088, 706, 711, 462, 351, 1120, 1140, 1014, 1144, 510}, closest bus: 711, closest main_bus: 982, min_distance: 0.00011221840312584099
# Connected bus 711 to 982 with New Line 105 Alimentador 678
# Number of disconnected sections: 32
# Closest section: {321, 1252, 645, 1257, 1258, 650, 1011, 797, 798}, closest bus: 1257, closest main_bus: 314, min_distance: 0.00012398983829755355
# Connected bus 1257 to 314 with New Line 106 Alimentador 678
# Number of disconnected sections: 31
# Closest section: {1040, 1033, 163, 151}, closest bus: 1040, closest main_bus: 1014, min_distance: 0.0001380297069458797
# Connected bus 1040 to 1014 with New Line 107 Alimentador 678
# Number of disconnected sections: 30
# Closest section: {161, 156}, closest bus: 156, closest main_bus: 163, min_distance: 9.176023102888481e-05
# Connected bus 156 to 163 with New Line 108 Alimentador 678
# Number of disconnected sections: 29
# Closest section: {1217, 1332}, closest bus: 1332, closest main_bus: 43, min_distance: 0.00014307078667001076
# Connected bus 1332 to 43 with New Line 109 Alimentador 678
# Number of disconnected sections: 28
# Closest section: {35, 1245, 1215}, closest bus: 1215, closest main_bus: 1332, min_distance: 0.0001967504256675598
# Connected bus 1215 to 1332 with New Line 110 Alimentador 678
# Number of disconnected sections: 27
# Closest section: {1058, 38, 1180, 1113, 410, 476, 541}, closest bus: 1058, closest main_bus: 1328, min_distance: 0.0003191882829949973
# Connected bus 1058 to 1328 with New Line 111 Alimentador 678
# Number of disconnected sections: 26
# Closest section: {669, 440, 391, 24, 1085}, closest bus: 391, closest main_bus: 1040, min_distance: 0.00036486941499651256
# Connected bus 391 to 1040 with New Line 112 Alimentador 678
# Number of disconnected sections: 25
# Closest section: {41, 1330, 137, 42}, closest bus: 1330, closest main_bus: 440, min_distance: 0.00011084926702177133
# Connected bus 1330 to 440 with New Line 113 Alimentador 678
# Number of disconnected sections: 24
# Closest section: {448, 417, 446, 447}, closest bus: 446, closest main_bus: 24, min_distance: 0.0003819491589210915
# Connected bus 446 to 24 with New Line 114 Alimentador 678
# Number of disconnected sections: 23
# Closest section: {1032, 648, 526, 655, 656, 657, 1047, 1050, 414, 672, 674, 676, 423, 1065, 1071, 1072, 1073, 566, 1335, 1336, 569, 1337, 1091, 584, 585, 727}, closest bus: 1091, closest main_bus: 417, min_distance: 0.0001624002770968613
# Connected bus 1091 to 417 with New Line 115 Alimentador 678
# Number of disconnected sections: 22
# Closest section: {658, 615}, closest bus: 615, closest main_bus: 656, min_distance: 8.642667412782424e-05
# Connected bus 615 to 656 with New Line 116 Alimentador 678
# Number of disconnected sections: 21
# Closest section: {578, 877, 174, 336, 282}, closest bus: 578, closest main_bus: 1330, min_distance: 0.00042104750325499423
# Connected bus 578 to 1330 with New Line 117 Alimentador 678
# Number of disconnected sections: 20
# Closest section: {899, 390, 295, 745, 1229, 45, 272, 529, 434, 213, 218, 955}, closest bus: 45, closest main_bus: 1337, min_distance: 0.0004499484081460852
# Connected bus 45 to 1337 with New Line 118 Alimentador 678
# Number of disconnected sections: 19
# Closest section: {293, 84, 88, 89, 90, 91, 92}, closest bus: 92, closest main_bus: 548, min_distance: 0.0009878864914505193
# Connected bus 92 to 548 with New Line 119 Alimentador 678
# Number of disconnected sections: 18
# Closest section: {302}, closest bus: 302, closest main_bus: 293, min_distance: 0.00031347633084050905
# Connected bus 302 to 293 with New Line 120 Alimentador 678
# Number of disconnected sections: 17
# Closest section: {1178}, closest bus: 1178, closest main_bus: 108, min_distance: 0.0011070162600407064
# Connected bus 1178 to 108 with New Line 121 Alimentador 678
# Number of disconnected sections: 16
# Closest section: {224, 356, 605, 614, 425, 1067, 204, 396, 219, 1075, 1076, 245, 598, 376, 601, 603, 604, 381}, closest bus: 224, closest main_bus: 108, min_distance: 0.003483785263183465
# Connected bus 224 to 108 with New Line 122 Alimentador 678
# Number of disconnected sections: 15
# Closest section: {836, 135, 840, 617, 394, 395, 844, 845, 494, 488, 671, 177, 659, 666, 1054, 159}, closest bus: 1054, closest main_bus: 1067, min_distance: 0.00026558990944568515
# Connected bus 1054 to 1067 with New Line 123 Alimentador 678
# Number of disconnected sections: 14
# Closest section: {673, 296, 298, 876, 654, 337, 339, 340, 308, 310, 852, 283, 318, 319}, closest bus: 654, closest main_bus: 671, min_distance: 0.0003794206768293863
# Connected bus 654 to 671 with New Line 124 Alimentador 678
# Number of disconnected sections: 13
# Closest section: None, closest bus: None, closest main_bus: None, min_distance: inf
# No closest bus or main bus found, exiting loop
# _____________ PANDAPOWER DIAGNOSTIC TOOL _____________
#
#
#  --------
#
# Checking for elements without a connection to an external grid...
#
# Disconnected section found, consisting of the following elements:
# buses: [3, 7]
# lines: [553]
# Disconnected section found, consisting of the following elements:
# buses: [225, 517]
# lines: [460]
# Disconnected section found, consisting of the following elements:
# buses: [170, 205, 243, 255, 257, 263, 270, 276, 287, 294, 301, 307, 323, 348, 366, 387, 422, 438, 474, 479, 620, 737, 748, 787, 812, 829, 858, 881, 900, 922, 924, 932, 969, 1031, 1036, 1056, 1083, 1101, 1128, 1162, 1171, 1172, 1224, 1237, 1278]
# lines: [640, 645, 646, 650, 651, 654, 657, 658, 665, 667, 668, 671, 683, 685, 687, 689, 690, 692, 696, 699, 701, 702, 706, 710, 711, 716, 719, 720, 726, 728, 729, 733, 736, 741, 742, 744, 746, 747, 748, 749, 751, 755, 634, 635]
# Disconnected section found, consisting of the following elements:
# buses: [9, 40, 46]
# lines: [1241, 1242]
# Disconnected section found, consisting of the following elements:
# buses: [10, 1133]
# lines: [265]
# Disconnected section found, consisting of the following elements:
# buses: [19]
# Disconnected section found, consisting of the following elements:
# buses: [29, 30]
# lines: [1247]
# Disconnected section found, consisting of the following elements:
# buses: [547]
# Disconnected section found, consisting of the following elements:
# buses: [123, 140, 166, 181, 183, 203, 207, 357, 368, 371, 386, 415, 428, 1098, 1103, 1105, 1112, 1127, 1130, 1137, 1141, 1153, 1159, 1168, 1170, 1196, 1201, 1210, 1211, 1226, 1240, 1248]
# lines: [779, 780, 781, 786, 791, 795, 797, 805, 806, 810, 811, 812, 814, 815, 822, 824, 825, 828, 830, 832, 838, 840, 845, 849, 854, 855, 864, 865, 866, 870, 879]
# Disconnected section found, consisting of the following elements:
# buses: [838, 902]
# lines: [739]
# Disconnected section found, consisting of the following elements:
# buses: [853]
# Disconnected section found, consisting of the following elements:
# buses: [980, 1382]
# lines: [380]
#
# SUMMARY: 178 disconnected element(s) found.
#
#  --------
#
#
#  --------
#
# Checking for impedance values close to zero...
#
# line 230: r_ohm <= 0.001 or x_ohm <= 0.001
# line 388: r_ohm <= 0.001 or x_ohm <= 0.001
# line 393: r_ohm <= 0.001 or x_ohm <= 0.001
# line 396: r_ohm <= 0.001 or x_ohm <= 0.001
# line 966: r_ohm <= 0.001 or x_ohm <= 0.001
# line 970: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1085: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1092: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1154: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1221: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1240: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1243: r_ohm <= 0.001 or x_ohm <= 0.001
# line 1245: r_ohm <= 0.001 or x_ohm <= 0.001
#
# SUMMARY: 13 element(s) with impedance values close to zero found.
#
#  --------
#
#
#  --------
#
#
#  --------
#
#
#  --------
#
#
#  --------
#
#
#  --------
#
#
#  --------
#
#
#  --------
#
#
#  --------
#
#
#  --------
#
#
#  --------
#
# _____________ END OF PANDAPOWER DIAGNOSTIC _____________
# This pandapower network includes the following parameter tables:
#    - bus (1290 element)
#    - ext_grid (1 elements)
#    - line (1289 element)
#    - bus_geodata (1385 element)
#  and the following results tables:
#    - res_bus (1385 element)
#    - res_line (1372 element)
#    - res_ext_grid (1 elements)
